# %% [markdown]
# # Navigation
#
# * What is the type of an object?
#
# * How to know the methods and properties of an object in Python?
#
# * What parameters does a method receive?
#
# * What does a method do?
#
# * What type the methods return?

# %%
import pandas as pd

# %%
object = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# %% [markdown]
# ## Type of object

# %%
type(object)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Method and properties of an object

# %%
dir(object)
# Out:
# ['A',
#  'B',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %% [markdown]
# ## Methods documentation

# %%
object.sample??

# %% [markdown]
# ## Help on a method, property or object

# %%
help(object.sample)
# Out:
# Help on method sample in module pandas.core.generic:
#
# sample(n: 'int | None' = None, frac: 'float | None' = None, replace: 'bool_t' = False, weights=None, random_state: 'RandomState | None' = None, axis: 'Axis | None' = None, ignore_index: 'bool_t' = False) -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Return a random sample of items from an axis of object.
#
#     You can use `random_state` for reproducibility.
#
#     Parameters
#     ----------
#     n : int, optional
#         Number of items from axis to return. Cannot be used with `frac`.
#         Default = 1 if `frac` = None.
#     frac : float, optional
#         Fraction of axis items to return. Cannot be used with `n`.
#     replace : bool, default False
#         Allow or disallow sampling of the same row more than once.
#     weights : str or ndarray-like, optional
#         Default 'None' results in equal probability weighting.
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Question 1
#
# What does the method `object.sum` do?

# %%
object.sum??

# %%
object.sum()
# Out:
# A     6
# B    15
# dtype: int64

# %% [markdown]
# <summary>
# <details>
# <summary>Click here for the solution</summary>
# <pre>
# help(object.sum)
# Return the sum of the values over the requested axis.
# </pre>
# </details>
# </summary>

# %% [markdown]
# ## Question 2
#
# What parameters does the method `object.sum` receive?

# %%
print(object.sum())
print(object['A'].sum())
# Out:
# A     6
# B    15
# dtype: int64
# 6

# %% [markdown]
# <summary>
# <details>
# <summary>Click here for the solution</summary>
# <pre>
# help(object.sum)
# axis: 'Axis | None' = 0, skipna: 'bool' = True, numeric_only: 'bool' = False, min_count: 'int' = 0, **kwargs
# </pre>
# </details>
# </summary>

# %% [markdown]
# ## Question 3
#
# What type does the method `object.sum` return?

# %% [markdown]
# <summary>
# <details>
# <summary>Click here for the solution</summary>
# <pre>
# help(object.sum)
# Returns Series or scalar
# </pre>
# </details>
# </summary>

# %% [markdown]
# ## Question 4
#
# What is the default values of the parameters of the method `object.sum`?

# %% [markdown]
# <summary>
# <details>
# <summary>Click here for the solution</summary>
# <pre>
# help(object.sum)
# axis : defaults to 0.
# skipna : bool, default True
# numeric_only : bool, default False
# min_count : int, default 0
# </pre>
# </details>
# </summary>
